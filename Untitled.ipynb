# %%
import csv
import json
import pprint

# %%
data_location = '..\_appdata\cli_money_tool\\'

reader = csv.DictReader(open(data_location + 'download.CSV', 'r'))

# %%
dict_list = []
for line in reader:
    dict_list.append(line)

# %%
total = 0

for i in dict_list:
    if i['CR/DR'] == 'DR' and float(i['Amount']) > 50.00:
        total += float(i['Amount'])
        pprint.pprint(f"""AMOUNT: ${float(i['Amount'])}
DESCRIPTION: {i['Description']}""")
print(f'Total: ${total}')
# Out:
# 'AMOUNT: $75.0\nDESCRIPTION: Check                  1683'
# ('AMOUNT: $500.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000099171644WEB 1510394779')
# ('AMOUNT: $1474.95\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000010628626WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036040511651PPD 9102000901')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: ATM W/D. 07/30 17:02 OLD SECOND NA RT 47@ WAUBON SUGAR '
#  'GROVE       IL  A5087539 CARD# *3557  TX# 000005954')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000093480425WEB 1510394779')
# ('AMOUNT: $1612.38\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000025070238WEB 5760039224')
# ('AMOUNT: $115.72\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010393267PPD 2360938600')
# ('AMOUNT: $98.29\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000010824707PPD 3135129825')
# ('AMOUNT: $74.66\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#076        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $1475.0\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000011022070WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036045930771PPD 9102000901')
# ('AMOUNT: $2000.0\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000025937811WEB 5760039224')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000096534764WEB 1510394779')
# ('AMOUNT: $93.1\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010368420PPD 2360938600')
# ('AMOUNT: $107.25\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000014232438PPD 3135129825')
# ('AMOUNT: $67.95\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#162        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $112.0\n'
#  'DESCRIPTION: AC FOX VALLEY PARK  RecTrac AD 071900760000073PPD 1366001059')
# ('AMOUNT: $105.32\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $1475.0\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000018673415WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036041765062PPD 9102000901')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000092662097WEB 1510394779')
# ('AMOUNT: $2900.85\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000025447083WEB 5760039224')
# ('AMOUNT: $96.77\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $69.06\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010431713PPD 2360938600')
# ('AMOUNT: $107.25\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000016015579PPD 3135129825')
# ('AMOUNT: $69.3\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#162        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $112.0\n'
#  'DESCRIPTION: AC FOX VALLEY PARK  RecTrac AD 071900760000070PPD 1366001059')
# ('AMOUNT: $1475.0\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000011309692WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036046720087PPD 9102000901')
# ('AMOUNT: $2377.71\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000026866024WEB 5760039224')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000091962477WEB 1510394779')
# ('AMOUNT: $60.04\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010388116PPD 2360938600')
# ('AMOUNT: $107.25\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000013604980PPD 3135129825')
# ('AMOUNT: $112.0\n'
#  'DESCRIPTION: AC FOX VALLEY PARK  RecTrac AD 071900760000067PPD 1366001059')
# ('AMOUNT: $153.99\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000013405137WEB PAYPALSI77')
# ('AMOUNT: $1475.0\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000014631573WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036042686479PPD 9102000901')
# ('AMOUNT: $55.36\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#081        DEBIT '
#  'TARGET             NAPERVIL IL')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000094697491WEB 1510394779')
# ('AMOUNT: $3274.58\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000025773316WEB 5760039224')
# ('AMOUNT: $57.09\n'
#  'DESCRIPTION: AC TARGET DEBIT CRD ACH TRAN 091000013368365WEB 1410215170')
# ('AMOUNT: $53.12\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010126119PPD 2360938600')
# ('AMOUNT: $102.83\n'
#  'DESCRIPTION: AC TARGET DEBIT CRD ACH TRAN 091000014425217WEB 1410215170')
# ('AMOUNT: $107.25\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000012144441PPD 3135129825')
# ('AMOUNT: $2000.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000090614720WEB 1510394779')
# ('AMOUNT: $112.0\n'
#  'DESCRIPTION: AC FOX VALLEY PARK  RecTrac AD 071900760000066PPD 1366001059')
# 'AMOUNT: $2000.0\nDESCRIPTION: Check                  1687'
# ('AMOUNT: $90.67\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#162        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $58.55\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#078        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $90.79\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#163        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $1457.05\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000017179954WEB PAYPALSI77')
# ('AMOUNT: $57.77\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#081        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036047683921PPD 9102000901')
# ('AMOUNT: $343.5\n'
#  'DESCRIPTION: POS PUR. 12/29 12:03 FOX VALLE FOX VALLEY C NAPERVILLE        '
#  'IL  10655000 CARD# *8780  TX# 000863433')
# ('AMOUNT: $65.38\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#075        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $87.44\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#084        DEBIT '
#  'TARGET             WARRENVI IL')
# ('AMOUNT: $100.0\n'
#  'DESCRIPTION: AC CAPITAL ONE N.A. CAPITALONE 065000093483023WEB 1510394779')
# ('AMOUNT: $2000.0\n'
#  'DESCRIPTION: AC CHASE CREDIT CRD EPAY 021000026608261WEB 5760039224')
# ('AMOUNT: $70.15\n'
#  'DESCRIPTION: AC COMED            UTIL_BIL 091000010282740PPD 2360938600')
# ('AMOUNT: $107.25\n'
#  'DESCRIPTION: AC HANOVER/CITIZENS PREM COLL 091000010874025PPD 3135129825')
# ('AMOUNT: $60.32\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $112.0\n'
#  'DESCRIPTION: AC FOX VALLEY PARK  RecTrac AD 071900760000069PPD 1366001059')
# ('AMOUNT: $1433.63\n'
#  'DESCRIPTION: AC PAYPAL           INST XFER 091000018393128WEB PAYPALSI77')
# ('AMOUNT: $291.93\n'
#  'DESCRIPTION: AC GREAT LAKES      STUDENT LN 041036043475605PPD 9102000901')
# ('AMOUNT: $79.47\n'
#  'DESCRIPTION: AC TARGET DEBIT CRD ACH TRAN 091000018178256WEB 1410215170')
# ('AMOUNT: $53.36\n'
#  'DESCRIPTION: TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#  'TARGET             OSWEGO   IL')
# ('AMOUNT: $807.0\n'
#  'DESCRIPTION: AC UNI              UNI U BIL 041000120632709WEB 5000074503')
# Total: $35982.91

# %%
total = 0

for i in dict_list:
    if i['CR/DR'] == 'CR':
        total += float(i['Amount'])
        #pprint.pprint(f"${float(i['Amount'])}")
print(f'Total: ${total}')
# Out:
# Total: $40754.77

# %%
total = 0

for i in dict_list:
    if i['CR/DR'] == 'DR':
        pprint.pprint(i)
print(f'Total: ${total}')
# Out:
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date',
00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/24/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000011701535WEB 1410215170'),
#              ('Amount', '000000006.69'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/26/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000017179954WEB PAYPALSI77'),
#              ('Amount', '000001457.05'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/26/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#081        DEBIT '
#               'TARGET             OSWEGO   IL'),
#              ('Amount', '000000057.77'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/27/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC GREAT LAKES      STUDENT LN 041036047683921PPD 9102000901'),
#              ('Amount', '000000291.93'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/30/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'POS PUR. 12/29 12:03 FOX VALLE FOX VALLEY C NAPERVILLE        '
#               'IL  10655000 CARD# *8780  TX# 000863433'),
#              ('Amount', '000000343.50'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '12/30/19'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#075        DEBIT '
#               'TARGET             OSWEGO   IL'),
#              ('Amount', '000000065.38'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/02/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#084        DEBIT '
#               'TARGET             WARRENVI IL'),
#              ('Amount', '000000087.44'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/02/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC CAPITAL ONE N.A. CAPITALONE 065000096545259WEB 1510394779'),
#              ('Amount', '000000020.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/02/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'NATHAN HOAD IAT PAYPAL 3.50 BEN HAMMOND 091000016085487  IAT   '
#               'US'),
#              ('Amount', '000000003.50'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/03/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC CAPITAL ONE N.A. CAPITALONE 065000093483023WEB 1510394779'),
#              ('Amount', '000000100.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/03/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000011889041WEB PAYPALSI77'),
#              ('Amount', '000000007.44'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/06/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC CHASE CREDIT CRD EPAY 021000026608261WEB 5760039224'),
#              ('Amount', '000002000.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/06/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC COMED            UTIL_BIL 091000010282740PPD 2360938600'),
#              ('Amount', '000000070.15'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/06/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000010740093WEB PAYPALSI77'),
#              ('Amount', '000000012.99'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/06/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000015074753WEB PAYPALSI77'),
#              ('Amount', '000000009.99'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/07/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC Orchard Valley C The Orchar 096016938641626WEB 0000166824'),
#              ('Amount', '000000050.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/07/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#163        DEBIT '
#               'TARGET             NORTH AU IL'),
#              ('Amount', '000000041.70'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/08/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC HANOVER/CITIZENS PREM COLL 091000010874025PPD 3135129825'),
#              ('Amount', '000000107.25'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/13/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#               'TARGET             OSWEGO   IL'),
#              ('Amount', '000000060.32'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/15/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000013857883WEB PAYPALSI77'),
#              ('Amount', '000000010.05'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/15/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000013860388WEB PAYPALSI77'),
#              ('Amount', '000000009.02'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/16/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC FOX VALLEY PARK  RecTrac AD 071900760000069PPD 1366001059'),
#              ('Amount', '000000112.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/21/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000015089367WEB 1410215170'),
#              ('Amount', '000000030.15'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/21/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000015089368WEB 1410215170'),
#              ('Amount', '000000005.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/22/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC Orchard Valley C The Orchar 096016939886848WEB 0000166824'),
#              ('Amount', '000000050.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/22/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000012703827WEB 1410215170'),
#              ('Amount', '000000013.42'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC PAYPAL           INST XFER 091000018393128WEB PAYPALSI77'),
#              ('Amount', '000001433.63'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC GREAT LAKES      STUDENT LN 041036043475605PPD 9102000901'),
#              ('Amount', '000000291.93'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000018178256WEB 1410215170'),
#              ('Amount', '000000079.47'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'TARGET DEBIT CRDACH TRAN TERM#074        DEBIT '
#               'TARGET             OSWEGO   IL'),
#              ('Amount', '000000053.36'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000017488444WEB 1410215170'),
#              ('Amount', '000000012.36'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/27/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC TARGET DEBIT CRD ACH TRAN 091000018178257WEB 1410215170'),
#              ('Amount', '000000005.00'),
#              ('CR/DR', 'DR')])
# OrderedDict([('Account Designator', 'Checking            '),
#              ('Posted Date', '01/28/20'),
#              ('Serial Number', '0000000000'),
#              ('Description',
#               'AC UNI              UNI U BIL 041000120632709WEB 5000074503'),
#              ('Amount', '000000807.00'),
#              ('CR/DR', 'DR')])
# Total: $0
